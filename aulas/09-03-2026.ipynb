# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plat
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
type(tips)
# Out:
# pandas.DataFrame

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='str')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
estatisticas = tips.groupby('time')['tip'].mean()

# %%
estatisticas
# Out:
# time
# Lunch     2.728088
# Dinner    3.102670
# Name: tip, dtype: float64

# %%
estatisticas = tips.groupby('time')['tip'].agg(['mean', 'median', 'std'])

# %%
estatisticas
# Out:
#             mean  median       std
# time
# Lunch   2.728088    2.25  1.205345
# Dinner  3.102670    3.00  1.436243

# %%
estatbill = tips.groupby('time')['total_bill'].mean()

# %%
estatbill
# Out:
# time
# Lunch     17.168676
# Dinner    20.797159
# Name: total_bill, dtype: float64

# %%
def simulador_cassino(n_jogadores= 10, saldo_inicial=200):
    custo = 20
    premios = [0, 1, 1, 2, 20, 20, 20, 30, 60] 
    resultados = []
    
    for n in range(n_jogadores):
        jogadas = 0
        max_saldo = saldo_inicial
        saldo = saldo_inicial
    
        while saldo >= custo:
            ganho = np.random.choice(premios)
            saldo = saldo +ganho - custo
            jogadas += 1
    
            if saldo > max_saldo:
                max_saldo = saldo
        resultados.append({"jogador": n+1, "total_jogadas": jogadas, "saldo_maximo": max_saldo})
        print(f"jogador {n}: {jogadas}")
    return pd.DataFrame(resultados)

# %%
jogos = simulador_cassino()
jogos
# Out:
# jogador 0: 27
# jogador 1: 143
# jogador 2: 113
# jogador 3: 65
# jogador 4: 36
# jogador 5: 32
# jogador 6: 209
# jogador 7: 15
# jogador 8: 52
# jogador 9: 45
#    jogador  total_jogadas  saldo_maximo
# 0        1             27           200
# 1        2            143           257
# 2        3            113           226
# 3        4             65           213
# 4        5             36           240
# 5        6             32           240
# 6        7            209           334
# 7        8             15           200
# 8        9             52           277
# 9       10             45           200

# %%
medias10 = []
for i in range (1000):
    jogos = simulador_cassino(100)
    medias10.append(jogos['total_jogadas'].mean())
# Out:
# jogador 0: 40
# jogador 1: 261
# jogador 2: 129
# jogador 3: 29
# jogador 4: 52
# jogador 5: 34
# jogador 6: 83
# jogador 7: 20
# jogador 8: 112
# jogador 9: 38
# jogador 10: 100
# jogador 11: 43
# jogador 12: 117
# jogador 13: 38
# jogador 14: 15
# jogador 15: 66
# jogador 16: 54
# jogador 17: 55
# jogador 18: 12
# jogador 19: 44
# jogador 20: 110
# jogador 21: 37
# jogador 22: 52
# jogador 23: 35
# jogador 24: 170
# jogador 25: 130
# jogador 26: 129
# jogador 27: 34
# jogador 28: 181
# jogador 29: 21
# jogador 30: 53
# jogador 31: 29
# jogador 32: 86
# jogador 33: 55
# jogador 34: 30
# jogador 35: 36
# jogador 36: 199
# jogador 37: 81
# jogador 38: 66
# jogador 39: 24
# jogador 40: 54
# jogador 41: 21
# jogador 42: 33
# jogador 43: 31
# jogador 44: 65
# jogador 45: 31
# jogador 46: 74
# jogador 47: 193
# jogador 48: 32
# jogador 49: 27
# jogador 50: 141
# jogador 51: 36
# jogador 52: 74
# jogador 53: 217
# jogador 54: 56
# jogador 55: 63
# jogador 56: 159
# jogador 57: 113
# ...

# %%
md10 = np
medias10 = [++]
for i in range (1000):
    jogos = simulador_cassino(100)
    medias10.append(jogos['total_jogadas'].mean())
