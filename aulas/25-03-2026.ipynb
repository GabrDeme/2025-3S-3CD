# %%
import numpy as np

# %%
a = [1, 2, 3, 4, 5, 6, 7, 8]
np.quantile(a, [0.25, 0.5, 0.75], method='weibull')
# Out:
# array([2.25, 4.5 , 6.75])

# %%
import plotly.express as px
import pandas as pd

# %% [markdown]
# distribuição de bernulli
#
# duas possibilidades (cara ou coroa)

# %%
numero_bolinhas = 1
probabilidade = 0.5 # probabilidade de ser 1

bolinhas = np.random.binomial(n=1, p=probabilidade, size=numero_bolinhas)
bolinhas
# Out:
# array([0], dtype=int32)
