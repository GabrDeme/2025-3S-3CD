# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
n_dias = 365

# %%
def simular_estoque(rop=150):
    np.random.normal(loc, scale, six = n_dias)
