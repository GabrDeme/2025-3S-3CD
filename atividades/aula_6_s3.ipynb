# %% [markdown]
# ## IF
# ### Selection Test 1
#
# Read 4 integer values A, B, C and D. Then if B is greater than C and D is greater than A and if the sum of C and D is greater than the sum of A and B and if C and D were positives values and if A is even, write the message “Valores aceitos” (Accepted values). Otherwise, write the message “Valores nao aceitos” (Values not accepted).
#
# **Input** <br>
# Four integer numbers A, B, C and D.
#
# **Output** <br>
# Show the corresponding message after the validation of the values​​.

# %%
print("Digite 4 números a seguir")

A = int(input("Digite o nº A: "))
B = int(input("Digite o nº B: "))
C = int(input("Digite o nº C: "))
D = int(input("Digite o nº D: "))

if (B > C and
    D > A and
    (C + D) > (A + B) and
    C > 0 and
    D > 0 and
    A % 2 == 0):
    print("Valores aceitos")
else:
    print("Valores não aceitos")
# Out:
# Digite 4 números a seguir
# Digite o nº A: 2
# Digite o nº B: 6
# Digite o nº C: 3
# Digite o nº D: 8
# Valores aceitos

# %% [markdown]
# ## FOR
# ### Odd Numbers
#
# Read an integer value X (1 <= X <= 1000).  Then print the odd numbers from 1 to X, each one in a line, including X if is the case.
#
# **Input** <br>
# The input will be an integer value.
#
# **Output** <br>
# Print all odd values between 1 and X, including X if is the case.

# %%
X = input()
try:
  X = int(X)
  if 1 <= X <= 1000:
    for i in range(1, X + 1):
      if i % 2 != 0:
        print(i)
except:
  print("Coloca um número que seja válido né, tem que ser entre 1 e 1000")
# Out:
# 10
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ## WHILE
# ### Fixed Password
#
# Write a program that keep reading a password until it is valid. For each wrong password read, write the message "Senha inválida". When the password is typed correctly print the message "Acesso Permitido" and finished the program. The correct password is the number 2002.
#
# **Input** <br>
# The input file contains several tests cases. Each test case contains only an integer number.
#
# **Output** <br>
# For each number read print a message corresponding to the description of the problem.

# %%
while True:
  password = input("Insira uma senha para prosseguir: ")
  try:
    password = int(password)
    if password == 2002:
      print("Acesso Permitido")
      break
    else:
      print("Senha Invalida")
  except:
    print("Tá moscando, tem que colocar número né paezão. Vai tentar de novo!")
# Out:
# Insira uma senha para prosseguir: a
# Tá moscando, tem que colocar número né paezão. Vai tentar de novo!
# Insira uma senha para prosseguir: 2002
# Acesso Permitido
